# %%
import pandas as pd
path='/workspace/public/data/project/basic_data/20160101_20181231.pq'
df = pd.read_parquet(path)
print('BACKEND: pandas')
print('Columns:', list(df.columns))
print('Rows:', len(df))
# Out:
# BACKEND: pandas
# Columns: ['open', 'close', 'high', 'low', 'pct_chg', 'pre_close', 'volume', 'amt', 'vwap', 'ul_price', 'trigger_price', 'raw_ZT_Time', 'ZT_Time', 'label_touch_ul_time', 'trigger_index', 'before_price1', 'before_price2', 'before_price', 'high_price', 'trigger_price_actual', 'max_rise_pct', 'label_pattern', 'label_firstUL_end_Time', 'label_lastUL_Time', 'label_lastUL_end_Time']
# Rows: 35062

# %%
print(df.head(30).to_string())
# Out:
#                         open   close    high    low  pct_chg  pre_close      volume           amt        vwap  ul_price  trigger_price  raw_ZT_Time      ZT_Time  label_touch_ul_time  trigger_index  before_price1  before_price2  before_price  high_price  trigger_price_actual  max_rise_pct  label_pattern  label_firstUL_end_Time  label_lastUL_Time  label_lastUL_end_Time
# dt         Ticker
# 2016-01-04 002109.SZ    9.39    9.39    9.39   9.00     9.95       8.54   183801.67  1.725116e+05    9.385746      9.39           9.38   93046330.0   93046330.0           93054790.0          864.0           9.27           9.35          9.27        9.39                  9.38      0.045667            3.0              93057610.0         94229360.0            150000000.0
# ...

# %%
import pandas as pd

md_data = pd.read_parquet("/workspace/public/data/project/other_data/MD_data/md_20120101_20250706.pq")
print(md_data.head())
# Out:
#                        open  close   high    low  pre_close  pct_chg  \
# dt         Ticker
# 2012-01-04 600613.SH   8.20   7.86   8.20   7.84       8.16    -3.68
#            600690.SH   9.00   8.78   9.17   8.78       8.93    -1.68
#            300277.SZ  22.90  20.88  22.98  20.81      22.68    -7.94
#            002403.SZ   8.87   8.40   8.90   8.40       8.84    -4.98
#            300179.SZ  19.99  19.50  20.32  19.20      19.96    -2.30
#
#                          volume          amt       vwap   mkt_cap_ard    turn  \
# dt         Ticker
# 2012-01-04 600613.SH    4762.98    3854.1000   8.091783  1.162533e+05  0.4657
#            600690.SH  142288.41  127992.6050   8.995294  2.357542e+06  0.5299
#            300277.SZ   12212.39   26797.1370  21.942582  1.398960e+05  8.9797
#            002403.SZ   10331.97    9013.4317   8.723827  2.016000e+05  1.0687
#            300179.SZ    1532.31    3008.0594  19.630880  1.560000e+05  0.7662
#
# ...

# %%
print(len(md_data[md_data["low"] == 0]))
print(len(md_data[md_data["pre_close"] == 0]))
print(len(md_data[md_data["pct_chg"] == 0]))
print(len(md_data[md_data["volume"] == 0]))
print(len(md_data[md_data["amt"] == 0]))
print(len(md_data[md_data["vwap"] == 0]))
print(len(md_data[md_data["mkt_cap_ard"] == 0]))
# Out:
# 0
# 0
# 344392
# 0
# 0
# 0
# 0
